# %%
import matplotlib.pyplot as plt
import cv2
import open3d as o3d

from  kitti_object import show_lidar_with_depth, show_lidar_on_image
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 5
#       2 import cv2
#       3 import open3d as o3d
# ----> 5 from  kitti_object import show_lidar_with_depth, show_lidar_on_image
#
# File d:\Workspace\Python\Point_Cloud_3D_Object_Detection\visualizer\kitti_object.py:18
#      15 BASE_DIR = os.path.dirname(os.path.abspath(__file__))
#      16 ROOT_DIR = os.path.dirname(BASE_DIR)
# ---> 18 from ..preprocess import kitti_utils as utils
#      20 import argparse
#      24 cbox = np.array([[0, 70.4], [-40, 40], [-3, 1]])
#
# ImportError: attempted relative import with no known parent package

# %%
dataset = kitti_object(r'E:\Storange\Python\Point_cloud\data\archive', 'training')

data_idx = 56
objects = dataset.get_label_objects(data_idx)
pc_velo = dataset.get_lidar(data_idx)
calib = dataset.get_calibration(data_idx)
img = dataset.get_image(data_idx)
img_height, img_width, _ = img.shape


show_lidar_with_depth(pc_velo, objects, calib,None, True, img_width, img_height)
# Out:
# E:\Storange\Python\Point_cloud\data\archive training
# E:\Storange\Python\Point_cloud\data\archive\training\velodyne\000067.bin
# ('All point num: ', 114305)
# ('FOV point num: ', (17696, 4))
# pc_velo (17696, 4)
# ==================== (17696, 4)
# box3d_pts_3d_velo:
# [[50.27678868 -4.88771659 -1.04150181]
#  [49.93859125 -6.32843533 -1.06025955]
#  [45.6163172  -5.31336714 -1.09470399]
#  [45.95451463 -3.8726484  -1.07594625]
#  [50.26299546 -4.90166285  0.27835253]
#  [49.92479803 -6.3423816   0.25959479]
#  [45.60252398 -5.32731341  0.22515035]
#  [45.94072142 -3.88659467  0.24390809]]
# box3d_pts_3d_velo:
# [[14.94439615 10.81774113 -1.87486262]
#  [15.5091458  13.35545408 -1.84214587]
#  [31.89733982  9.70667003 -1.70943504]
#  [31.33259017  7.16895708 -1.74215179]
#  [14.90238953 10.77526841  2.14469378]
#  [15.46713918 13.31298136  2.17741053]
#  [31.8553332   9.6641973   2.31012136]
#  [31.29058354  7.12648436  2.27740462]]
# box3d_pts_3d_velo:
# [[40.7911946  -5.89898121 -1.09131049]
#  [40.35926151 -7.39785395 -1.11166231]
#  [36.36213502 -6.24559261 -1.14125912]
#  [36.7940681  -4.74671987 -1.12090731]
#  [40.77635644 -5.91398402  0.32853281]
#  [40.34442335 -7.41285675  0.308181  ]
#  [36.34729686 -6.26059541  0.27858419]
#  [36.77922994 -4.76172267  0.298936  ]]
# box3d_pts_3d_velo:
# [[14.48905217  1.76740466 -1.49519876]
#  [14.00318522  0.25360511 -1.51627194]
#  [10.72792611  1.30514919 -1.53938906]
#  [11.21379306  2.81894874 -1.51831589]
#  [14.47390053  1.7520849  -0.04535876]
#  [13.98803357  0.23828535 -0.06643194]
#  [10.71277447  1.28982942 -0.08954907]
#  [11.19864142  2.80362898 -0.06847589]]
# box3d_pts_3d_velo:
# [[13.79792048  5.64846056 -1.54142105]
#  [13.27538448  4.12576835 -1.5629714 ]
#  [ 9.19894914  5.52505518 -1.59078684]
#  [ 9.72148514  7.04774739 -1.56923649]
#  [13.78214187  5.63250687 -0.03158768]
#  [13.25960587  4.10981466 -0.05313803]
#  [ 9.18317053  5.50910149 -0.08095346]
#  [ 9.70570653  7.03179371 -0.05940311]]
# box3d_pts_3d_velo:
# [[42.00644716  6.31605772 -1.58961067]
#  [42.16666783  7.65642274 -1.57377328]
#  [45.37366187  7.27272638 -1.54431273]
#  [45.2134412   5.93236136 -1.56015012]
#  [41.99140001  6.30084361 -0.14976957]
#  [42.15162068  7.64120863 -0.13393218]
#  [45.35861472  7.25751227 -0.10447163]
#  [45.19839405  5.91714725 -0.12030902]]
# box3d_pts_3d_velo:
# [[ 8.35740975e+01 -4.72736083e+00 -1.15188274e+00]
#  [ 8.27388460e+01 -2.29693554e+00 -1.13493045e+00]
#  [ 9.66021652e+01  2.46603636e+00 -9.39722966e-01]
#  [ 9.74374168e+01  3.56110739e-02 -9.56675261e-01]
#  [ 8.35379426e+01 -4.76391695e+00  2.30773545e+00]
#  [ 8.27026910e+01 -2.33349167e+00  2.32468775e+00]
#  [ 9.65660103e+01  2.42948023e+00  2.51989523e+00]
#  [ 9.74012618e+01 -9.45051985e-04  2.50294294e+00]]

# %%
print("Số điểm point cloud:", pc_velo.shape)
# Out:
# Số điểm point cloud: (114305, 4)

# %%
import numpy as np

pc_velo = pc_velo[np.random.choice(pc_velo.shape[0], 10000, replace=False)]

# %%
img_lidar = show_lidar_on_image(pc_velo[:, :3], img, calib, img_width, img_height)
img_lidar = cv2.cvtColor(img_lidar, cv2.COLOR_BGR2RGB)

fig_lidar = plt.figure(figsize=(14, 7))
ax_lidar = fig_lidar.subplots()
ax_lidar.imshow(img_lidar)
plt.show()

# %%
img_bbox2d, img_bbox3d = show_image_with_boxes(img, objects, calib)
img_bbox2d = cv2.cvtColor(img_bbox2d, cv2.COLOR_BGR2RGB)

fig_bbox2d = plt.figure(figsize=(14, 7))
ax_bbox2d = fig_bbox2d.subplots()
ax_bbox2d.imshow(img_bbox2d)
plt.show()

# %%
img_bbox3d = cv2.cvtColor(img_bbox3d, cv2.COLOR_BGR2RGB)

fig_bbox3d = plt.figure(figsize=(14, 7))
ax_bbox3d = fig_bbox3d.subplots()
ax_bbox3d.imshow(img_bbox3d)
plt.show()

# %%
img_bev = show_lidar_topview_with_boxes(pc_velo, objects, calib)

fig_bev = plt.figure(figsize=(7, 14))
ax_bev = fig_bev.subplots()
ax_bev.imshow(img_bev)
plt.show()
# Out:
# top_image: (500, 300, 3)
